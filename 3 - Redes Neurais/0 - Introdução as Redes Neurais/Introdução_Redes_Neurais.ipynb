# %% [markdown]
# # $$Introdução ~as~Redes~Neurais:$$

# %% [markdown]
# ### $$Conceitos:$$
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
# São técnicas computacionais que apresentam um modelo matemático inspirado na estrutura neural de organismos inteligentes e que adquirem conhecimento através da experiência.
#
#
#
#
#
# ### $$Características:$$
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
# **Deep Learning:**  Arquitetura da Rede Neural
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
#
#
# **Função de Ativação:** Processa o sinal gerado pela combinação linear das entradas e dos pesos das sinapses, para gerar o sinal de saída do neurônio, podendo ter resposta lineares e não-lineares
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
#
#
# **Épocas:** Quantas vezes os dados passam pela rede
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
#
#
#
#
# **Early Stopping:** Melhoria não está mais ocorrendo? Pare!, técnica para evitar o overfitting.
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
#
#
# **Dropout:** Diminui a capacidade de memorização do neurônio excluindo aleatoriamente alguns neurônios de algumas camadas, evitando overfitting
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
#
#
# **Arquiteturas esparsas:** São arquiteturas com menos conexões entre camadas
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
#
#
# **Camada:** Cada camada criar uma separação entre os dados, quando mais camadas mais os dados estão propensos a overfitting
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
#
#
# **Camada Densa:** Conecta cada neurônio em uma camada com todos os neurônios da camada anterior
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
#
#
# **Descida do gradiente:** Processo utilizado para encontrar o mínimo da função custo com base em variação nos pesos, através do processo de backpropagation os erros obtidos após os cálculos dos pesos são retroalimentados na rede até otimizarmos o resultado
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
# **Função de Custo:**
#
#
#
# - Função que mensura o quanto estamos acertando
#
#
#
#
#
# - São diferentes para variáveis contínuas e categóricas
#
#
#
#
#
# - **Contínuas:** MSE, MAE
#
#
#
#
#
# - **Categoricas:** Binary cross-entropy, Categorical cross-entropy
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
#
#
# ### $$Otimizadores:$$
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
# - **Descida do gradiente** = Taxa de aprendizado fixa
#
#
#
#
#
# - **ADAM, RMSPROP, ADAGRAD** = Taxa de aprendizado que varia com as iterações
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
#
#
# ### $$Tipos~de~Redes~Neurais:$$
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
#
#
# **Redes neurais rasas (shallow):**
#
#
#
# Possui apenas uma camada oculta, trata apenas de dados linearmente separáveis
#
#
#
#
#
# **Perceptron (P), Feed Forward Network (FFN), Radial Basis Network (RBF)** = São o tipo mais básico, onde a informação de entrada flui em sequência linear até a saída.
#
#
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
# **Redes neurais profundas:**
#
#
#
# Quando as redes neurais possuem muitas camadas ocultas (deep learning), trata-se de dados não linearmente separáveis.
#
#
#
# -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# __------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------__
#
#
# __------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------__

# %% [markdown]
# ## $$Objetivo:$$
#
# ## $$Compreender~ os~ principais~ conceitos~ das~ Redes~Neurais$$

# %% [markdown]
# __------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------__
#
#
# __------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------__

# %%
#Importar as bibliotecas
import numpy as np
import pandas as pd

# %% [markdown]
# # Base de dados

# %%
#Carregar dataset
dados = pd.read_csv('winequality-red.csv',encoding='latin1',sep=',')
dados
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# **Temos 1599 observações e 12 variáveis**

# %% [markdown]
# # Análise Exploratória

# %%
#Tipos de dados
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# **Todas as variáveis númericas**

# %% [markdown]
# # Modelagem:

# %%
#Separar os dados em X e Y
x = dados.iloc[:,0:11]
y = dados.quality

#Padronização dos dados

dados_padro = (x - x.mean()) / (x.std())
dados_padro
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.528194          0.961576    -1.391037       -0.453077  -0.243630
# 1         -0.298454          1.966827    -1.391037        0.043403   0.223805
# 2         -0.298454          1.296660    -1.185699       -0.169374   0.096323
# 3          1.654339         -1.384011     1.483689       -0.453077  -0.264878
# 4         -0.528194          0.961576    -1.391037       -0.453077  -0.243630
# ...             ...               ...          ...             ...        ...
# 1594      -1.217415          0.403103    -0.980362       -0.382151   0.053829
# 1595      -1.389721          0.123866    -0.877693       -0.240300  -0.541090
# 1596      -1.159980         -0.099523    -0.723690       -0.169374  -0.243630
# 1597      -1.389721          0.654416    -0.775024       -0.382151  -0.264878
# 1598      -1.332285         -1.216469     1.021680        0.752659  -0.434854
#
# ...

# %% [markdown]
# **Padronizar os dados para deixar todas as variáveis na mesma escala**

# %%
#Divisão dos dados 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dados_padro,y,test_size=0.3,random_state=1)

#Alterar as dimensoes
X_train = X_train.T
X_test = X_test.T
y_train = pd.DataFrame(y_train).T
y_test = pd.DataFrame(y_test).T

# %% [markdown]
# **As redes neurais feedforward avançam da esquerda para direita, por isso fazemos a transposição dos dados para deixar as variáveis em linhas**

# %% [markdown]
# # Parte 1 - Criar arquitetura da rede

# %%
#Arquitetura
def arq_func(x,y,hidden_neurons):
    n_x = x.shape[0] #quantidade de linhas de x = neurônios da camada de entrada
    n_h = hidden_neurons #quantidade de neurônios na camada escondida
    n_y = y.shape[0] #quantidade de linhas de y = neurônios da camada de saída
    arquite = {'n_x': n_x, 'n_h': n_h, 'n_y': n_y}
    return(arquite)
    
    
#Aplicar a função arquitetura de rede
arq_rede = arq_func(X_train, y_train , 4)
arq_rede
# Out:
# {'n_x': 11, 'n_h': 4, 'n_y': 1}

# %% [markdown]
# **Na primeira etapa, criamos a arquitetura da rede, passando os valores das variáveis de entrada ('n_x), camada oculta ('n_h') e saída ('n_y')**

# %% [markdown]
# # Parte 2 - Inicializar os Parâmetros randomicamente

# %%
#Inicializar pesos
from random import randrange, uniform

def init_pesos(x, arquite):
    n_x = arquite.get('n_x')
    n_h = arquite.get('n_h')
    n_y = arquite.get('n_y')
    
    W1 = np.full((n_h, n_x), np.random.rand(n_h, n_x))*0.01
    W2 = np.full((n_y, n_h), np.random.rand(n_y, n_h))*0.01
    
    params_pesos = {'W1': W1, 'W2': W2}
    return(params_pesos)
    
    
    
inic_pesos = init_pesos(X_train,arq_rede)
inic_pesos
# Out:
# {'W1': array([[0.00758344, 0.00209783, 0.00301845, 0.00177113, 0.00653467,
#          0.00775537, 0.0002061 , 0.00454198, 0.00329526, 0.00162838,
#          0.00271277],
#         [0.00933011, 0.00453312, 0.00311695, 0.00373894, 0.00086175,
#          0.00699999, 0.00494025, 0.00899104, 0.00430462, 0.00237281,
#          0.0058667 ],
#         [0.00947949, 0.00464732, 0.00711105, 0.00313039, 0.00212756,
#          0.0070036 , 0.00506203, 0.0046907 , 0.00955357, 0.0083051 ,
#          0.00272503],
#         [0.00166528, 0.00965172, 0.00953038, 0.00447054, 0.0072426 ,
#          0.00920033, 0.00957219, 0.00910913, 0.00691683, 0.00231826,
#          0.00825453]]),
#  'W2': array([[0.00926757, 0.00826552, 0.00462925, 0.00362835]])}

# %% [markdown]
# **A partir da arquitetura, inicializamos os parâmetros (pesos e bias) randomicamente. O primeiro conjunto ('W1') são os pesos da camada de entrada com a camada intermediaria. O segundo ('W2') são os pesos da camada intermediaria com a camada de saída**

# %% [markdown]
# # Parte 3 - Função de ativação - Sigmoide

# %%
#Formula
def sig(x):
    return((1/(1+np.exp(-x))))

# %% [markdown]
# **Formula da função de ativação(Sigmoide) para aplicar dentro do Forward Propagation**

# %% [markdown]
# # Parte 4 - Forward Propagation

# %%
def forward_prop(x,params_pesos,arquite):
    
    n_h = arquite.get('n_h')
    n_y = arquite.get('n_y')
    
    W1 = params_pesos.get('W1')
    W2 = params_pesos.get('W2')
    
    
    Z1 = np.dot(W1,x) #Multiplicação entre camada de entrada X Pesos
    A1 = sig(Z1) #Função Sigmoide do resultado da Multiplicação entre Camada de entrada X Pesos (Camada Oculta)
    Z2 = np.dot(W2,A1) #Multiplicação entre o resultado da sigmoide X pesos da camada intermediaria (Entre camada oculta e saida)
    prev1 = sig(Z2) #Função Sigmoide no resultado da multiplicação de Z2 (Camada de saida)
    
    cache = {'Z1':Z1, 'A1':A1, 'Z2':Z2, 'prev1':prev1}

    return (cache)
    
    
forward_1 = forward_prop(X_train,inic_pesos,arq_rede)
forward_1
# Out:
# {'Z1': array([[-0.00359823, -0.02372713, -0.00449255, ..., -0.00574451,
#          -0.01190847, -0.00621806],
#         [ 0.00391987, -0.03006112, -0.0074667 , ..., -0.00788276,
#          -0.01906477, -0.0092354 ],
#         [-0.00013787, -0.038975  , -0.01293352, ..., -0.01743642,
#          -0.0206969 , -0.00839456],
#         [ 0.01438753, -0.04198503, -0.01532762, ...,  0.00085552,
#          -0.02292866, -0.01475752]]),
#  'A1': array([[0.49910044, 0.49406849, 0.49887686, ..., 0.49856388, 0.49702292,
#          0.49844549],
#         [0.50097997, 0.49248528, 0.49813333, ..., 0.49802932, 0.49523395,
#          0.49769117],
#         [0.49996553, 0.49025748, 0.49676667, ..., 0.49564101, 0.49482596,
#          0.49790137],
#         [0.50359682, 0.48950528, 0.49616817, ..., 0.50021388, 0.49426809,
#          0.49631069]]),
#  'Z2': array([[0.012908  , 0.01269509, 0.01284064, ..., 0.01284635, 0.01278362,
#          0.01283876]]),
# ...

# %% [markdown]
# **Agora com todas as informações dos pesos e estrutura da rede, iniciamos o processo de geração de resultados, multiplicação das matrizes (Variáveis e pesos)**

# %% [markdown]
# # Parte 5- Cost Function

# %%
def funcao_custo(y, cache):
    
    
    m = y.shape[1]
    
    y = y.values[0]
    
    prev1 = cache.get('prev1')[0]

    cost = sum((y-prev1)**2)/m
    
    return (cost)


custo_1 = funcao_custo(y_train,forward_1)
custo_1
# Out:
# 27.219447569045972

# %% [markdown]
# **Função de custo: Mean Squared Error, função que vai calcular o quanto a rede está acertando**

# %% [markdown]
# # Parte 6 - Backpropagation

# %%
def backwardPropagation(x, y, cache, params_pesos, arquite):
    
    m = x.shape[1]
    
    n_x = arquite.get('n_x')
    n_h = arquite.get('n_h')
    n_y = arquite.get('n_y')

    prev1 = cache.get('prev1')[0]
    A1 = cache.get('A1')
    W2 = params_pesos.get('W2')

    
    dZ2 = prev1 - y #Valor previsto - Valor real (Diferença para alterar os pesos)
    dW2 = 1/m * np.dot(dZ2, A1.T) #Quanto eu preciso alterar os pesos de W2

    
    dZ1 = np.dot(W2.T,dZ2) * (1 - A1**2)#Mudança que ocorre na camada intermediaria para camada de entrada em funçao de DZ2
    dW1 = 1/m * np.dot(dZ1 , x.T) #Quanto eu preciso alterar os pesos de W1 em função de W2

    
    grads = {'dW1':dW1, 'dW2':dW2}
   
    
    return(grads)


gradiente = backwardPropagation(X_train,y_train,forward_1,inic_pesos,arq_rede)
gradiente
# Out:
# {'dW1': array([[-7.54693886e-04,  1.67824242e-03, -8.69392702e-04,
#           2.16568585e-04,  5.27905947e-04,  1.24076318e-03,
#           2.04148617e-03,  1.18421892e-03, -2.91388227e-04,
#          -1.72864479e-03, -3.55918631e-03],
#         [-6.41774517e-04,  1.51247978e-03, -7.64345177e-04,
#           2.35570062e-04,  4.21021590e-04,  1.12906015e-03,
#           1.86158248e-03,  1.09830266e-03, -2.57909076e-04,
#          -1.54749835e-03, -3.16234676e-03],
#         [-3.73519315e-04,  8.35864602e-04, -4.20859364e-04,
#           1.21517382e-04,  2.50776093e-04,  6.36427751e-04,
#           1.04448028e-03,  6.01985031e-04, -1.30132463e-04,
#          -8.33101307e-04, -1.76617966e-03],
#         [-3.15194170e-04,  6.83866783e-04, -3.42893872e-04,
#           1.14043508e-04,  2.12108938e-04,  5.23298426e-04,
#           8.50040087e-04,  4.66527235e-04, -9.25196890e-05,
#          -6.74048349e-04, -1.38437039e-03]]),
# ...

# %% [markdown]
# **Após o cálculo da função de custo, é feito o ajuste dos pesos, o backpropagation dá a direção (valor positivo ou negativo) e o valor para que seja atualizado os pesos**

# %% [markdown]
# # Parte 7 - Atualizar os pesos

# %%
def updateParameters(grads, params_pesos, learning_rate):
    
    W1 = params_pesos.get('W1')
    W2 = params_pesos.get('W2')
    
    dW1 = grads.get('dW1')
    dW2 = grads.get('dW2')
    
    
    W1 = W1 - learning_rate * dW1 #Atualizar peso W1
    W2 = W2 - learning_rate * dW2 #Atualizar peso W2
    
    updated_pesos = {'W1': W1, 'W2': W2}
    
    
    return (updated_pesos)


atualiza_pesos = updateParameters(gradiente,inic_pesos,learning_rate = 0.1)
atualiza_pesos
# Out:
# {'W1': array([[7.65891021e-03, 1.93001051e-03, 3.10539323e-03, 1.74947103e-03,
#          6.48188195e-03, 7.63129295e-03, 1.94971973e-06, 4.42356129e-03,
#          3.32440301e-03, 1.80124389e-03, 3.06868410e-03],
#         [9.39428430e-03, 4.38187172e-03, 3.19338760e-03, 3.71537845e-03,
#          8.19646553e-04, 6.88707912e-03, 4.75408737e-03, 8.88121034e-03,
#          4.33041084e-03, 2.52756008e-03, 6.18293892e-03],
#         [9.51683991e-03, 4.56373682e-03, 7.15313940e-03, 3.11824053e-03,
#          2.10248110e-03, 6.93995399e-03, 4.95757898e-03, 4.63050005e-03,
#          9.56658617e-03, 8.38840729e-03, 2.90164950e-03],
#         [1.69679474e-03, 9.58333018e-03, 9.56466877e-03, 4.45913995e-03,
#          7.22138611e-03, 9.14800099e-03, 9.48718302e-03, 9.06247231e-03,
#          6.92607715e-03, 2.38566143e-03, 8.39296733e-03]]),
#  'W2': array([[0.26691067, 0.26590572, 0.26229974, 0.26121461]])}

# %% [markdown]
# **Com o valor do backpropagation é feita atualização dos pesos, para que na próxima iteração o valor do custo seja menor, por isso diminuímos o valor do peso atual pelo peso adquirido pelo backpropagation, não podendo esquecer da taxa de aprendizado**

# %% [markdown]
# # Parte 9 - Treinar o modelo

# %%
def trainModel(x, y, num_iteration, hidden_neurons, learning_rate):
    
    arq_rede = arq_func(x, y, hidden_neurons)
    init_params = init_pesos(x, arq_rede)
    
    cost_history = []
    

    for i in range(1,num_iteration):
        fwd_prop = forward_prop(x, init_params, arq_rede)
        cost = funcao_custo(y, fwd_prop)
        back_prop = backwardPropagation(x, y, fwd_prop, init_params, arq_rede)
        update_params = updateParameters(back_prop, init_params, learning_rate = learning_rate)
        init_params = update_params
        cost_history.append(cost)
        
        
        
    
    
    model_out = {'cost_hist': cost_history}


    return (model_out)


modelo_final = trainModel(X_train,y_train,num_iteration=20,hidden_neurons=20,learning_rate=0.01)
modelo_final
# Out:
# {'cost_hist': [27.12861433496577,
#   26.47711946295498,
#   25.865451189838183,
#   25.307512501535584,
#   24.811300720008592,
#   24.379435095053243,
#   24.01032917540289,
#   23.69955168043195,
#   23.441063454937698,
#   23.22818285470427,
#   23.054253373407022,
#   22.913052994566797,
#   22.799007908048086,
#   22.70727212254037,
#   22.633723118651247,
#   22.574910163827134,
#   22.527979983706405,
#   22.490595315653156,
#   22.460855393482444]}

# %% [markdown]
# **Loop de todo o processo, note que conforme a rede neural vai fazendo iterações o erro vai diminuindo**

# %% [markdown]
# # Conclusão:

# %% [markdown]
# **Em uma rede neural há uma série de parâmetros a serem ajustados, dependendo da quantidade de dados e o tipo da variável respostas, temos que ir modificando a estrutura da rede, não há um padrão para que consiga chegar no melhor resultado, apenas com testes podemos fazer as comparações**
