# %% [markdown]
# # $$Processo~ Hierárquico ~Analítico (AHP)$$

# %% [markdown]
# ### $$Conceito:$$
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
# **Tomada de Decisão:**
#
#
#
#
#
# Uma decisão precisa ser tomada sempre que estamos diante de um problema que possui mais de uma alternativa para sua solução. Mesmo quando, para solucionar um problema, possuímos uma única ação a tomar, temos as alternativas de tomar ou não essa ação
#
#
#
# O processo de decisão requer a existência de um conjunto de alternativas factíveis para sua composição, em que cada decisão tem associados um ganho e uma perda
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
# **Métodos Multicritério:**
#
#
#
# Problemas de tomada de decisão multicritério são caracterizados por uma Matriz de Decisão, sendo composta de alternativas e critérios ponderados de acordo com o tomador de decisão em questão. Métodos para solucionar problemas MCDM têm sido amplamente utilizados para selecionar a melhor alternativa entre um número finito de alternativas.
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
# **Métodos AHP:**
#
#
#
# O Analytic Hierarchy Process (AHP) é um método para auxiliar às pessoas na tomada de decisões complexas. Mais do que determinar qual a decisão correta, o AHP ajuda as pessoas a escolher e a justificar a sua escolha.
#
#
#
# O AHP é um método de tomada de decisão multicritério simples de usar e flexível. Permite a avaliação de problemas complexos, baseados em critérios conflitantes entre si. É adequado para diferentes problemáticas, uma vez que a mesma dependa da interação humana para conduzir o processo de comparação. Entre as vantagens de usar AHP como modelo de análise decisória, é a viabilização de considerar diferentes níveis de importâncias entre as variáveis
#
#
#
# Baseando-se nos modelos de Apoio Multicritério à Decisão (AMD), o método AHP baseia-se em uma análise hierárquica das variáveis. Neste modelo, um conjunto de alternativas é avaliado segundo as preferências do agente decisor quanto aos critérios de influência, buscando uma alternativa favorável para o alcance eficiente do objetivo estratégico.
#
#
#
# Uma das principais características do método é viabilização de trabalhar com questões subjetivas quanto as atribuições de desempenho das variáveis do problema. Simplificando, na aplicação do método AHP, não é necessário definir um número preciso quanto ao desempenho de uma alternativa em um dado critério, onde uma atribuição verbal já satisfaz o modelo. As atribuições do método AHP são realizadas com base em uma escala proposta por Thomas Saaty
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
# ### $$Caracteristica~ do~ método ~AHP:$$
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
# **Monotônico de Lucro:** quanto maior, melhor
#
#
#
#
#
# **Monotônico de Custo:** quanto menor, melhor
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
#
#
# **Transitividade:** Se A  B e B  C , então: A  C
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
#
#
# **Teste de Consistência:** O AHP viabiliza calcular uma razão de consistência (CR) mediante a comparação do Índice de Consistência (CI) das atribuições do decisor quanto a um índice de consistência de uma matriz aleatória (RI)
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
#
#
# ### $$Processo ~Geral~ do~ Modelo: Estrutura~ Axiomáticas$$
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
#
#
# **Definição do conjunto de critérios e alternativas:**
#
#
#
# Construção da matriz de avaliação composta pelo conjunto de alternativas e critérios em avaliação
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
#
#
# **Avaliação dos critérios(Escala Saaty):**
#
#
#
# Atribuição dos julgamentos de importância entre os critérios;
#
#
#
# Teste de consistência das atribuições;
#
#
#
# Procedimento algébrico para obtenção do vetor prioridade e pesos doscritérios (𝑤𝑗)
#
#
#
# Obtenção das prioridades dos critérios
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
# **Avaliação das alternativas em cada critério:**
#
#
#
#
#
# Atribuição dos julgamentos de importância entre as alternativas em cada critério;
#
#
#
# Teste de consistência das atribuições;
#
#
#
# Procedimento algébrico para obtenção do vetor prioridade para cada alternativa em cada critério (𝑎𝑖𝑗).
#
#
#
# Obtenção das prioridades locais das alternativas em cada critério
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
#
#
#
#
#
#
# **Processo de agregação das preferências:**
#
#
#
# Ponderação dos vetores prioridades das alternativas pelos pesos dos respectivos critérios (𝑤𝑗𝑎𝑖𝑗)
#
#
#
# Soma das prioridades (σ 𝑤𝑗𝑎𝑖𝑗).
#
#
#
# Obtenção das prioridades globais das alternativas na problemática
#
#
#
# -----------------------------------------------------------------------------------------------------------------------
#
#
#
#
# **OBS: Número máximo de 15 critérios pode ser usado nesse método**

# %%
#Escala Saaty
from IPython.display import Image
Image(filename="Saaty1.png",width=600)

# %%
#Matriz RI
from IPython.display import Image
Image(filename="RI.png")

# %%
#C
from IPython.display import Image
Image(filename="C.png")

# %% [markdown]
# **Para que um conjunto de atribuições seja consistente, precisa-se obter um C.R ≤ 10%**

# %% [markdown]
# __------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------__
#
#
# __------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------__

# %% [markdown]
# ## $$Objetivo:$$
#
# ## $$Escolher~a~melhor~marca~de  ~Smartphone~ de~ acordo~ com~ os ~dados$$$$~ abaixo, ~usando~ o~ método~ AHP$$

# %% [markdown]
# __------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------__
#
#
# __------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------__

# %%
#Dados

from IPython.display import Image
Image(filename="dados.png")

# %%
#Importar as bibliotecas
import numpy as np
import pandas as pd

# %% [markdown]
# # 1° Estruturação do problema

# %%
# Criterios

criterios = ['custo','camera','armazenamento','bateria']

# %%
#Alternativas

alt = ['xiaomi','samsung','iphone']

# %% [markdown]
# **Após ter definido os critérios e alternativas, vamos analisar os critérios, viabilizando a obtenção de suas respectivas importâncias**

# %% [markdown]
# ## 2° Avaliação Par a Par dos critérios: Matriz de Ponderações(ou Jugamentos)

# %%
#Criar martiz de 1
matriz = pd.DataFrame(np.ones((4, 4),dtype=int),columns=criterios)
#Add nome nas linhas
matriz.index = criterios
matriz
# Out:
#                custo  camera  armazenamento  bateria
# custo              1       1              1        1
# camera             1       1              1        1
# armazenamento      1       1              1        1
# bateria            1       1              1        1

# %% [markdown]
# **Criado a matriz com valor 1, pois o critério em diagonal está sendo comparado com ele mesmo**

# %% [markdown]
# ## 3° Preencher a matriz com base na Escala Saaty

# %% [markdown]
# **Grau de Importância:**
#
#
# Custo VS Camera = 3
#
# Custo VS armazenamento = 5
#
# Custo VS bateria = 7
#
# camera VS armazenamento = 3
#
# camera VS bateria = 7
#
# armazenamento VS bateria = 3
#
#
# **Recíproca:**
#
# Camera VS Custo = 1/3
#
# armazenamentoVS Custo  = 1/5
#
# bateria VS Custo = 1/7
#
# armazenamento VS camera = 1/3
#
# bateria VS camera = 1/7
#
# bateria VS armazenamento = 1/3

# %% [markdown]
# **O preenchimento dos valores de acordo com o critério é de forma subjetiva**

# %%
#Preencher
matriz['custo'] = [1,1/3,1/5,1/7]
matriz['camera'] = [3,1,1/3,1/7]
matriz['armazenamento'] = [5,3,1,1/3]
matriz['bateria'] = [7,7,3,1]

matriz_saaty = round(matriz,3)
matriz_saaty
# Out:
#                custo  camera  armazenamento  bateria
# custo          1.000   3.000          5.000        7
# camera         0.333   1.000          3.000        7
# armazenamento  0.200   0.333          1.000        3
# bateria        0.143   0.143          0.333        1

# %% [markdown]
# **Observe o Axioma da Reciprocidade, Se custo VS camera = 3, então camera VS custo = 1/3**

# %% [markdown]
# **Obs: Diagonal com valor 1 se manteve**

# %% [markdown]
# ## 4° Processo de normalização (deixar os dados das colunas no formato de porcentagem)

# %%
#Transposta para somar as colunas
matrizt = matriz_saaty.T

# Somar as colunas
matrizt['Soma_Total'] = matrizt.aggregate(np.sum,axis=1)

#Voltar a matriz original
matriz = matrizt.T
matriz
# Out:
#                custo  camera  armazenamento  bateria
# custo          1.000   3.000          5.000      7.0
# camera         0.333   1.000          3.000      7.0
# armazenamento  0.200   0.333          1.000      3.0
# bateria        0.143   0.143          0.333      1.0
# Soma_Total     1.676   4.476          9.333     18.0

# %% [markdown]
# **Criado uma linha com o somatório total das colunas para o processo de normalização**

# %%
#Formula da normalização (dado da Coluna / dado da Soma_Total)
matriz = matriz/matriz.iloc[4,:]
matriz = matriz.iloc[0:4,:]
matriz
# Out:
#                   custo    camera  armazenamento   bateria
# custo          0.596659  0.670241       0.535733  0.388889
# camera         0.198687  0.223414       0.321440  0.388889
# armazenamento  0.119332  0.074397       0.107147  0.166667
# bateria        0.085322  0.031948       0.035680  0.055556

# %% [markdown]
# **Matriz de ponderações normalizados**

# %% [markdown]
# ## 5° Criar Vetor de prioridade

# %%
#Formula (Soma das linhas / numero de colunas)

matriz['Vetor_prioridade'] = matriz.aggregate(np.sum,axis=1)/len(matriz.columns)
matriz
# Out:
#                   custo    camera  armazenamento   bateria  Vetor_prioridade
# custo          0.596659  0.670241       0.535733  0.388889          0.547881
# camera         0.198687  0.223414       0.321440  0.388889          0.283108
# armazenamento  0.119332  0.074397       0.107147  0.166667          0.116885
# bateria        0.085322  0.031948       0.035680  0.055556          0.052126

# %% [markdown]
# **Vetor de prioridades são os pesos de cada critério (em porcentagem), onde o somatório é 100%**

# %% [markdown]
# ## 6° Calcular a Razão de Consistência

# %%
# Calculo: matriz com base na Escala Saaty * Vetor de prioridades

consistencia = matriz_saaty * matriz['Vetor_prioridade']
consistencia
# Out:
#                   custo    camera  armazenamento   bateria
# custo          0.547881  0.849323       0.584427  0.364885
# camera         0.182444  0.283108       0.350656  0.364885
# armazenamento  0.109576  0.094275       0.116885  0.156379
# bateria        0.078347  0.040484       0.038923  0.052126

# %% [markdown]
# **Distribuição da importância de cada critério de acordo com a escala Saaty**

# %% [markdown]
# ## 7° Soma dos pesos da Consistência

# %%
## Calculo da soma dos pesos(Soma das linhas)

consistencia['soma_pesos'] = consistencia.sum(axis=1)
consistencia
# Out:
#                   custo    camera  armazenamento   bateria  soma_pesos
# custo          0.547881  0.849323       0.584427  0.364885    2.346516
# camera         0.182444  0.283108       0.350656  0.364885    1.181093
# armazenamento  0.109576  0.094275       0.116885  0.156379    0.477116
# bateria        0.078347  0.040484       0.038923  0.052126    0.209881

# %% [markdown]
# **Variável soma_pesos é importante para definir o lambda máximo e calcular o resultado da C.I**

# %% [markdown]
# ## 8° Obtenção do lambda máximo

# %%
# Calculo da obtenção do lambda máximo

# Calculo 1: (Soma_pesos/Vetor_prioridade)
lambda_calculo1 = consistencia['soma_pesos']/matriz['Vetor_prioridade']
lambda_calculo1
# Out:
# custo            4.282896
# camera           4.171889
# armazenamento    4.081908
# bateria          4.026375
# dtype: float64

# %%
# Calculo 2: soma dos resultados
lambda_calculo2 = lambda_calculo1.sum()
lambda_calculo2
# Out:
# 16.56306827139555

# %%
#Calculo do lambda máximo

#Calculo 3: soma dos resultados/ numero de critérios
lambda_maximo = lambda_calculo2/len(lambda_calculo1)
lambda_maximo
# Out:
# 4.140767067848888

# %% [markdown]
# **Valor do lambda máximo**

# %% [markdown]
# ## 9° Calcular o C.I

# %%
# Formula do C.I:

#C.I = (Lambda máximo - numero critérios) / (numero critérios -  1)

c_i = (lambda_maximo - len(lambda_calculo1)) / (len(lambda_calculo1) - 1)
c_i
# Out:
# 0.046922355949629235

# %% [markdown]
# **Valor do C.I**

# %% [markdown]
# ## 10° Calcular o C.R

# %%
# Formula do C.R:

# C.R = C.I / R.I

# %%
#Matriz RI
from IPython.display import Image
Image(filename="RI.png")

# %% [markdown]
# **Veja que a matriz de ordem 4 é usado o valor de 0.9 para calcular a C.R**

# %%
#Calculo do C.R

c_r = c_i/0.9

#Converter para Porcentagem
round(c_r*100,2)
# Out:
# 5.21

# %% [markdown]
# **Valor da razão de consistência é de 5.21%**

# %% [markdown]
# **Como o valor da razão de consistência foi ≤ 10%, então o julgamento do decisor foi bom, pois ele foi consistente e preservou a transitividade matemática**

# %% [markdown]
# # 11° Processo de normalização dos dados originais

# %%
# Dados originais

#Criar martiz de 1
dados = pd.DataFrame(np.ones((3, 4),dtype=int),columns=criterios)
#Add nome nas linhas
dados.index = alt

#Alterar os valores com os dados originais
dados['custo'] = [1500, 1800 , 5000]
dados['camera'] = [12,12,20]
dados['armazenamento'] = [64,128,128]
dados['bateria'] = [24,18,10]

#Dados originais
dados
# Out:
#          custo  camera  armazenamento  bateria
# xiaomi    1500      12             64       24
# samsung   1800      12            128       18
# iphone    5000      20            128       10

# %% [markdown]
# **Dados originais**

# %%
# Normalizar os dados Monotônico de Custo


# Monotônico de Custo: Inverter o valor para normalizar = 1/valor
dados['custo'] = 1/dados['custo']
dados
# Out:
#             custo  camera  armazenamento  bateria
# xiaomi   0.000667      12             64       24
# samsung  0.000556      12            128       18
# iphone   0.000200      20            128       10

# %% [markdown]
# **Observe que o custo do iphone que era o valor mais caro, agora passou a ser o valor mais baixo com a normalização para avaliação dos dados, pois os dados de custo quanto menor, melhor**

# %%
# Somatorio do custo
dados['custo'].sum()
# Out:
# 0.0014222222222222223

# %%
#Calculo final para normalização da coluna custo

#Indice de preferencia local
dados['custo'] = dados['custo']/dados['custo'].sum()
dados.iloc[:,0].to_frame()
# Out:
#             custo
# xiaomi   0.468750
# samsung  0.390625
# iphone   0.140625

# %% [markdown]
# **Cálculo do Índice de preferência local do critério: custo**

# %%
# Normalizar os dados Monotônico de Lucro

# Monotônico de Lucro: Não precisa inverter os dados pois já estão na ordem correta, quanto maior melhor

#Indice de preferencia local
dados['camera'] = dados['camera']/dados['camera'].sum()
dados['armazenamento'] = dados['armazenamento']/dados['armazenamento'].sum()
dados['bateria'] = dados['bateria']/dados['bateria'].sum()
dados
# Out:
#             custo    camera  armazenamento   bateria
# xiaomi   0.468750  0.272727            0.2  0.461538
# samsung  0.390625  0.272727            0.4  0.346154
# iphone   0.140625  0.454545            0.4  0.192308

# %% [markdown]
# **Índice de preferência local de todos os critérios**

# %% [markdown]
# # 12° Processo de agregação

# %%
# 12° Função de Agregação

# Calculo : Matriz normalizada * Vetor de pesos
resultado_final = dados*matriz['Vetor_prioridade']

#Soma para identificar a prioridade de cada produto pela sua prioridade final
resultado_final['Prioridade_final'] = resultado_final.sum(axis=1)
resultado_final
# Out:
#             custo    camera  armazenamento   bateria  Prioridade_final
# xiaomi   0.256819  0.077211       0.023377  0.024058          0.381466
# samsung  0.214016  0.077211       0.046754  0.018044          0.356025
# iphone   0.077046  0.128685       0.046754  0.010024          0.262509

# %% [markdown]
# **Índice de preferência global: Xiaomi ficou em 1° lugar na preferência de compra de smartphone, seguidos por Samsung e Iphone**

# %% [markdown]
# __------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------__
#
#
# __------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------__

# %% [markdown]
# # $$Método~AHP~ Gaussiano$$

# %% [markdown]
# ### $$Conceito:$$
#
# O Método AHP-Gaussiano apresenta uma nova abordagem ao método original, baseada em uma análise de sensibilidade proveniente do fator gaussiano
#
# Com essa abordagem é possível obter os pesos dos critérios mediante as entradas quantitativas das alternativas em cada critério em análise, ou seja, a partir dos dados da própria matriz de decisão.
#
# Um dos pontos de destaque do novo modelo relaciona-se a redução do esforço cognitivo do decisor, a partir do momento em que não é mais necessário a avaliação par a par entre os critérios para obtenção de seus respectivos pesos
#
# Entretanto, vale ressaltar, que a viabilidade do modelo só é satisfeita em cenários em que as alternativas possuam entradas cardinais nos critérios em análise
#
# **OBS: Não há um número máximo de critérios para ser usado nesse método**

# %% [markdown]
# __------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------__
#
#
# __------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------__

# %% [markdown]
# ## $$Objetivo:$$
#
# ## $$Escolher~a~melhor~marca~de  ~Smartphone~ de~ acordo~ com~ os ~dados$$$$~ abaixo, ~usando~ o~ método~ AHP~Gaussiano$$

# %% [markdown]
# __------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------__
#
#
# __------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------__

# %% [markdown]
# ## Etapa 1 – Determinação da Matriz de Decisão

# %%
# Dados originais

#Criar martiz de 1
dados = pd.DataFrame(np.ones((3, 4),dtype=int),columns=criterios)
#Add nome nas linhas
dados.index = alt

#Alterar os valores com os dados originais
dados['custo'] = [1500, 1800 , 5000]
dados['camera'] = [12,12,20]
dados['armazenamento'] = [64,128,128]
dados['bateria'] = [24,18,10]

#Dados originais
dados
# Out:
#          custo  camera  armazenamento  bateria
# xiaomi    1500      12             64       24
# samsung   1800      12            128       18
# iphone    5000      20            128       10

# %% [markdown]
# **Dados originais**

# %%
# Normalizar os dados
dados_norm = dados.copy()

# Monotônico de Custo: Inverter o valor para normalizar = 1/valor
dados_norm['custo'] = 1/dados_norm['custo']
# Somatorio do custo
dados_norm['custo'].sum()
#Indice de preferencia local Monotônico de Custo
dados_norm['custo'] = dados_norm['custo']/dados_norm['custo'].sum()
#Indice de preferencia local Monotônico de Lucro
dados_norm['camera'] = dados_norm['camera']/dados_norm['camera'].sum()
dados_norm['armazenamento'] = dados_norm['armazenamento']/dados_norm['armazenamento'].sum()
dados_norm['bateria'] = dados_norm['bateria']/dados_norm['bateria'].sum()
dados_norm
# Out:
#             custo    camera  armazenamento   bateria
# xiaomi   0.468750  0.272727            0.2  0.461538
# samsung  0.390625  0.272727            0.4  0.346154
# iphone   0.140625  0.454545            0.4  0.192308

# %% [markdown]
# **Dados normalizados no formato de porcentagem**

# %% [markdown]
# ## Etapa 2 – Cálculo da média das alternativas em cada critério

# %%
#Média da base de dados = Somatório das colunas / número de critérios

media = dados_norm.sum(axis=0)/3
media
# Out:
# custo            0.333333
# camera           0.333333
# armazenamento    0.333333
# bateria          0.333333
# dtype: float64

# %% [markdown]
# **Valor da média de cada coluna**

# %% [markdown]
# ## Etapa 3 – Cálculo do desvio padrão dos critérios com base na amostra das alternativas

# %%
#Desvio padrão da base de dados original
desv = dados_norm.std()
desv
# Out:
# custo            0.171401
# camera           0.104973
# armazenamento    0.115470
# bateria          0.135072
# dtype: float64

# %% [markdown]
# **desvio padrão de cada criterio**

# %% [markdown]
# ## Etapa 4 – Cálculo do fator gaussiano para cada critério

# %%
#Fator gaussiano
f_gaussiano = desv/media
f_gaussiano
# Out:
# custo            0.514203
# camera           0.314918
# armazenamento    0.346410
# bateria          0.405217
# dtype: float64

# %% [markdown]
# **Fator gaussiano de cada critério**

# %%
#Somatorio do Fator gaussiano
f_gaussiano.sum()
# Out:
# 1.5807485256924703

# %% [markdown]
# **Note que o fator gaussiano não da 1, portanto teremos que normalizar os dados**

# %%
#Transformar em porcentagem o fator gaussiano
f_gau_porcent = f_gaussiano / f_gaussiano.sum()
print(f_gau_porcent)
print(f'\nSomatória: {f_gau_porcent.sum()}')
# Out:
# custo            0.325291
# camera           0.199221
# armazenamento    0.219143
# bateria          0.256345
# dtype: float64
#
# Somatória: 1.0

# %% [markdown]
# **Note que agora a somatória da 1**

# %% [markdown]
# ## Etapa 5 – Ponderação da matriz de decisão

# %%
#Ponderações dos dados
pond_matriz = dados_norm * f_gau_porcent
pond_matriz
# Out:
#             custo    camera  armazenamento   bateria
# xiaomi   0.152480  0.054333       0.043829  0.118313
# samsung  0.127067  0.054333       0.087657  0.088735
# iphone   0.045744  0.090555       0.087657  0.049297

# %% [markdown]
# **Definida a importância de cada critério**

# %% [markdown]
# ## Etapa 6 – Obtenção do Ranking

# %%
#Ranking
pond_matriz['Soma_Ponderacoes'] = pond_matriz.sum(axis=1)
pond_matriz
# Out:
#             custo    camera  armazenamento   bateria  Soma_Ponderacoes
# xiaomi   0.152480  0.054333       0.043829  0.118313          0.368955
# samsung  0.127067  0.054333       0.087657  0.088735          0.357792
# iphone   0.045744  0.090555       0.087657  0.049297          0.273253

# %% [markdown]
# **Com base no valor da ponderação de cada critério, podemos definir a ordem do melhor produto sendo: 1° Xiaomi, 2° Samsung e 3° Iphone**

# %% [markdown]
# # Comparação dos 2 Métodos

# %%
# Adicionar as Ponderações do método 1
dados['Metodo_1'] = resultado_final['Prioridade_final']

# Adicionar as Ponderações do método 2
dados['Metodo_2'] = pond_matriz['Soma_Ponderacoes']

dados
# Out:
#          custo  camera  armazenamento  bateria  Metodo_1  Metodo_2
# xiaomi    1500      12             64       24  0.381466  0.368955
# samsung   1800      12            128       18  0.356025  0.357792
# iphone    5000      20            128       10  0.262509  0.273253

# %% [markdown]
# **Observe que os 2 métodos tiveram a mesma ordem de importância dos produtos, com uma pequena variação no valor final das ponderações**

# %% [markdown]
# # Conclusão:

# %% [markdown]
# **Apesar do resultado final dos 2 métodos serem parecidos, o método AHP Gaussiano, não tem a premissa do uso máximo de critérios e não usa a escala Saaty para definir a importância de cada critério**
